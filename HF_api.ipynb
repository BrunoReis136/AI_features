# %% [markdown]
# <a href="https://colab.research.google.com/github/BrunoReis136/AI_features/blob/main/HF_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q diffusers transformers accelerate safetensors
# !pip install -U torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q python==3.10

# %%
import torch
print(torch.cuda.is_available())
print(torch.version.cuda)
# Out:
# True
# 12.6

# %%
import torch
from diffusers import StableDiffusionPipeline

# dispositivo
device = "cuda" if torch.cuda.is_available() else "cpu"

# carregar pipeline (uma única vez)
pipe = StableDiffusionPipeline.from_pretrained(
    "HiDream-ai/HiDream-I1-Fast",
    torch_dtype=torch.float16
)

pipe = pipe.to(device)

# (opcional) otimizações
pipe.enable_attention_slicing()
pipe.safety_checker = None  # remove filtro NSFW (opcional)

# gerar imagem
prompt = "Astronaut riding a horse, cinematic, ultra detailed, 4k"

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.5
).images[0]

image
